# %% [markdown]
# <a href="https://colab.research.google.com/github/CrisFiss/Colab-Notebooks/blob/master/Language_Identification_FES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2>Daniel Vasilyonok</h2>
# <h3>Python for Data Science CSCI E - 29</h3>
# <h3>Natural Language Identification Machine Learning Pipeline - Graduate Project</h3>
#
# <p>
# In this project, I pulled text data from European Parliament Proceedings in 21 languages.
# Using Scikit-Learn, I transformed the raw text into a numerical feature matrix, and trained
# a Multinomial naive bayes probability model to classify input language with greater than 99% accuracy.
# </p>
#
# <p>
# Data Source: http://www.statmt.org/europarl/
# </p>

# %%
# Required libraries

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import re
from nltk.tokenize import sent_tokenize
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
import os
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pandas as pd
from urllib.request import urlopen

# %%
# regular expression pattern used to filter out anything between < >
# Non predictive speaker information in english is always in between those two symbols

pattern = r'<(!?).*>'

# Max length of language transcription
# Ensure each language has similar amount of representation (Balanced Dataset)
MAX_LENGTH_TRANSCRIPTION = 150000

# %%
# Map language index to natural language

labels = { 
          1.0:'German',
          2.0: 'English', 
          3.0: 'Spanish'
          }

# Map language to language code and file name

language_codes_files = {
    'German': ['de', '/ep-00-01-17.txt'], 
    'English': ['en', '/ep-00-01-17.txt'], 
    'Spanish': ['es', '/ep-00-01-17.txt']
}

# These languages need multiple files combined to get a transcription of length
# >= MAX_LENGTH_TRANSCRIPTION
limited_raw_text = []

# %% [markdown]
# <h2>Helper Functions</h2>

# %%
# Helper Functions

def combine_text_files(language_code, language):
   
    '''
    Goal: Certain languages do not have a single file of length >= MAX_LENGTH_TRANSCRIPTION
          This function will combine these files for this sort of language into one language
          transcription, and then write the transcription to a single file.
    
    @param: (string) language_code is the 2 character code of the language
    @param: (string) language is the English name of the language         
    '''    
    
    file_name_list = urlopen('https://raw.githubusercontent.com/CrisFiss/dataset-idiomas/tree/master/language_data/txt' + language_code + '/')
    language_transcription = ''
    for file_name in file_name_list:
        if(len(language_transcription) >= MAX_LENGTH_TRANSCRIPTION):
            break;
        path = 'https://raw.githubusercontent.com/CrisFiss/dataset-idiomas/tree/master/language_data/txt/' + language_code + '/' + file_name
        with open(path, 'r', errors='ignore') as f:
            contents = f.read()
            language_transcription += contents
    
    write_path = 'https://raw.githubusercontent.com/CrisFiss/dataset-idiomas/tree/master/language_data/txt/' + language_code + '/' + language + '.txt'
    with open(write_path, 'w', errors='ignore') as f:
        f.write(language_transcription)

def read_languages_data(path):
    '''
    Goal: Read language data from file path into a list containing one massive string
    
    @param path: (string) file path pointing to the raw natural language text
                 Original file data source found here: http://www.statmt.org/europarl/
    @return language_transcription: (list) language_transcription is a list of one string containing the whole text
    '''
    with open(path, 'r', errors='ignore') as f:
        language_transcription = f.read()
        language_transcription = language_transcription[:MAX_LENGTH_TRANSCRIPTION]
    return language_transcription

def clean_sentences(sentences):
    '''
    Goal: Filter out non predictive text about speaker using regular expression pattern
    
    @param sentences: (list) sentences is a list of strings, where each string is a sentence.
                       Note: The raw language_transcription should be tokenized by sentence prior
                       to being passed into this function.
    '''
    for i, sentence in enumerate(sentences):
        sentences[i] = re.sub(pattern,'',sentence)

def combine_language_data(sentences, language_index):
    '''
    Goal: Transform list of string sentences into np.array, and stack horizontally with an np.array containing 
          the sentence's language_index, which maps to the sentence language. Essentially, apply label to data.
    
    @param sentences: (list) sentences is a list of strings that has had speaker information filtered out
    @param language_index: (float) language_index is a float that maps to a specific language in the labels dictionary
    @return language_data: (np.array) return an np.array of shape (# of sample sentences, 2 )
    '''
    sentences = np.array(sentences)
    sentences = sentences.reshape(sentences.shape[0],1)
    target = np.zeros((sentences.shape[0],1))
    target += language_index
    language_data = np.hstack((sentences, target))
    return language_data

def test_languages(X_test, true_values, predictions):
    '''
    Goal: Visualize the ~99% prediction accuracy by comparing,
        1. natural language sentence
        2. predicted natural language
        3. true natural language
    
    @param X_test: (np.array) X_test is a np.array containing the unseen data from the test set
    @param true_values: (np.array) true_values is a np.array containing the true language_index labels
    @param predictions: (np.array) predictions is a np.array containing the predicted language_index labels
    '''
    
    true_values = np.array(true_values)
    
    for i, sentence in enumerate(X_test):
        prediction = float(predictions[i])
        true_value = float(true_values[i])
        print("Prediction: " + str(labels[prediction]))
        print("Actual Language: " + str(labels[true_value]))
        print("Input Sentence: ")
        print(sentence)
        print('\n')

def shuffle_rows(languages):
    '''
    Goal: Shuffle rows of 2D np.array with language data
    
    @param languages: un-mixed 2D np.array with language sentence features, and language_index labels
    @return shuffled_languages: shuffled by row, 2D np.array 
    '''
    
    index = np.arange(0, len(languages))
    np.random.shuffle(index)
    shuffled_languages = languages[index,:]

    return shuffled_languages
    
def preproccess_raw_data(file_paths):
    '''
    Goal: Run all data preprocessing helper functions
    
    @param file_paths: (list) file_paths is a list of string file paths. Each file path string
                        points to a raw text file from the European Parliament Proceedings.
    @return languages: (np.array) languages is a 2D np.array of shape (# sentences, 2)
                        The first dimension has the a sentence, and the second dimension
                        has the language_index label, that maps to the language.
    '''
    
    # Combine transcriptions of subset languages into a single file to ensure
    # each file will have len >= MAX_LENGTH_TRANSCRIPTION
    language_codes_files_subset = dict( (key, language_codes_files[key] ) for key in limited_raw_text if key in language_codes_files )
    for language in language_codes_files_subset.keys():
        combine_text_files(language_codes_files_subset[language][0], language)
    
    # Read all raw text data from file paths
    language_transcriptions = [ read_languages_data(path) for path in file_paths ]
    
    # tokenize each raw text string into a list of sentences
    for i, language_transcription in enumerate(language_transcriptions):
        language_transcriptions[i] = sent_tokenize(language_transcription)
    
    # Remove information about speakers using a regular expression pattern
    for sentences in language_transcriptions:
        clean_sentences(sentences)
    
    # Combine each language with its language_index
    languages = [ combine_language_data(sentences,i+1) for i,sentences in enumerate(language_transcriptions) ]
    
    # Vertically stack all data into one 2D np.array
    languages =  np.vstack((languages))
    
    # Shuffle languages by row
    languages = shuffle_rows(languages)
    
    return languages

# %%
# Get all file paths

file_paths = [ os.getcwd() + '/language_data/txt/' + language_codes_files[language][0] + language_codes_files[language][1] for language in language_codes_files ]

# Preprocess all raw text into a form suitable for TfidfVectorizer
languages = preproccess_raw_data(file_paths)
languages
# Out:
# array([['\nThe vote will take place tomorrow at 12 p.m.\n\n\nTransport of dangerous goods by road\n\nThe next item is the report (A5-0104/1999) by Mr Koch, on behalf of the Committee on Regional Policy, Transport and Tourism, on the proposal for a European Parliament and Council directive amending Directive 94/55/EC on the approximation of the laws of the Member States with regard to the transport of dangerous goods by road [COM(1999) 158 - C5-0004/1999 - 1999/0083(COD)].',
#         '2.0'],
#        ['Dies ist gerade im Hinblick auf die neuen Anforderungen an die Haushaltsdisziplin von Bedeutung.',
#         '1.0'],
#        ['Die Fraktion der Sozialdemokratischen Partei Europas in diesem Parlament ist mit dem von Herrn Berend vorgetragenen Bericht einverstanden und beglÃ¼ckwÃ¼nscht seinen Verfasser sowohl zur QualitÃ¤t seiner SchluÃŸfolgerungen als auch zu seiner FlexibilitÃ¤t, durch die im AusschuÃŸ Ã„nderungsantrÃ¤ge der verschiedenen Fraktionen aufgenommen werden konnten.',
#         '1.0'],
#        ...,
#        ['\nTransport safety has sadly been in the news recently: the Paddington rail crash in London, the terrible rail crash in Norway, the two aviation crashes involving EU citizens and the natural disaster involving the Erika off Brittany - all within the last four months - remind us that transport safety can never be taken for granted and that those charged with protecting the public must be highly motivated and highly qualified.',
#         '2.0'],
#        ['Ich nutze diese Gelegenheit, um zu fragen, ob uns die Kommission Ã¼ber die GrÃ¼nde aufklÃ¤ren kann, warum sich der Bericht der Kommission Ã¼ber die Gebiete in Ã¤uÃŸerster Randlage verzÃ¶gert, der im Parlament seit lÃ¤ngerem erwartet wird.',
#         '1.0'],
#        ['De este modo la tan cacareada necesidad de transparencia en el uso de estos fondos y la tentaciÃ³n de recurrir innecesariamente lo mÃ¡s tarde posible a la base tributaria local en las zonas donde esos proyectos se desarrollan disminuirÃ¡n, y el Parlamento Europeo mostrarÃ¡ que se toma con seriedad la necesidad de esa reforma.',
#         '3.0']], dtype='<U863')

# %%
df_languages = pd.DataFrame(languages)
df_languages.columns = ['natural language', 'language index']
df_languages['language index'] = df_languages['language index'].apply(float)
df_languages['language'] = df_languages['language index'].map(labels)
print(df_languages.isnull().any())
display(df_languages.head(10))
# Out:
# natural language    False
# language index      False
# language            False
# dtype: bool
#                                     natural language  language index language
# 0  \nThe vote will take place tomorrow at 12 p.m....             2.0  English
# 1  Dies ist gerade im Hinblick auf die neuen Anfo...             1.0   German
# 2  Die Fraktion der Sozialdemokratischen Partei E...             1.0   German
# 3  Mit Hilfe von Leitlinien soll den Mitgliedstaa...             1.0   German
# 4  \nDistinguido seÃ±or Presidente, estimados col...             3.0  Spanish
# 5  \nUnserer Auffassung nach ist die Zusammenarbe...             1.0   German
# 6  \nAngesichts der jÃ¼ngsten Naturkatastrophen m...             1.0   German
# 7  \nSeÃ±or Presidente, seÃ±or Comisario, disting...             3.0  Spanish
# 8  Die Mitteilungen der einzelnen Regierungen zu ...             1.0   German
# 9  Ihre WettbewerbsfÃ¤higkeit steigt, aber der wa...             1.0   German

# %%
df_languages.shape
# Out:
# (2630, 3)

# %%
# Split data into raw features and labels

language_features = df_languages['natural language']
language_targets = df_languages['language index']

# %% [markdown]
# Ensure Dataset is relativley balanced.

# %%
unique, counts = np.unique(language_targets, return_counts=True)
dict(zip(unique, counts))
# Out:
# {1.0: 896, 2.0: 890, 3.0: 844}

# %%
# Split data into training and test set
# Train on 70% of data, Test on remaining 30%

X_train, X_test, y_train, y_test = train_test_split(language_features, 
                                                    language_targets,
                                                    test_size = 0.3,
                                                    random_state = 42)

# %% [markdown]
# <h2>Machine Learning Pipeline</h2>
#
# <h3>Feature Engineering / Preprocessing</h3>
# <p>With the clean raw text sentences in hand, the natural languages are preprocessed using Scikit-Learn's
# TfidfVectorizer. Essentially, the raw text sentences are converted into a numerical feature matrix.
# Tfidf stands for Term frequency inverse document frequency, and the arguments I used are analyzer = 'char' and
# ngram_range = (1,3). Analyzer = 'char' tells the vectorizer to look at characters rather than words.
# ngram_range = (1,3) tells the vectorizer to assign tfidf scores to character sequences with max length of 3 characters
# and minimum length of 1 character. From doing some linguistic reasearch, I found that short character ngram sequences
# are predictive features of a natural languages.
# <br>
# <br>
# <b>How does TfidfVectorizer work in this situation?</b>
# <p>The count of each ngram is recorded and divided by the total ngrams in a sentence.
# This number is the tf (Term Frequency) in tfidf. Next, the term frequency is scaled down
# by being multiplied by how common it is in all sentences. This factor used by TfidfVectorizer in Scikit-Learn is
# 1 + log(# sentences / # of sentences that contain the ngram). If an ngram is highly reccurent in many sentences, this
# inverse document frequency term (idf) gets smaller, and brings down the overall tfidf score. The idf term makes it so that words like the,of, or frequently used articles do not have too much weight in an ngram's score. The output of TfidfVectorizer is a numerical feature matrix that has maps the ngram index to its tfidf score. This can be passed into a Machine Learning model.</p>
# <h3>Naive Bayes Multinomial Model</h3>
# <p> In a Naive Bayes Multinomial Model, features are assumed to be generated from a multinomial distribution, rather than the slightly more simple Gaussian Naive Bayes model that assumes features are generated from a Gaussian distribution. The Multinomial Naive Bayes model is modeled with the best fit multinomial distribution. The model
# works by computing a large table of probabilities with the given data. Using the Liklihood -- P(feature|Label), the Prior-- P(Label), and the Marginal Liklihood-- P(feature), the model takes advatage of Baye's Theorm to compute
# P(Label|feature). The P(Label|feature) with the highest probability gets predicted as the correct language.
# </p>

# %%
# Make Machine Learning Pipeline with TfidfVectorizer and MultinomialNB

tfidf_vect = TfidfVectorizer(analyzer='char', ngram_range=(1,3))
model = MultinomialNB()
text_clf = Pipeline([('tfidf', tfidf_vect),
                    ('clf', model),
                    ])

# %%
# Train model with pipeline classifier

text_clf.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='char', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 3), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
# Make predictions on unseen test data with trained classifier

predictions = text_clf.predict(X_test)

# %%
# Measure accuracy

accuracy_score(y_test,predictions)
# Out:
# 0.9987325728770595

# %% [markdown]
# <h1>Cross Validated Accuracy</h1>

# %%
# alternate train and test set through cross validation to yield a more trustworthy accuracy

scores = cross_val_score(text_clf, language_features, language_targets, cv=5)
print("Mean cross-validation accuracy: " + str(scores.mean()))
# Out:
# Mean cross-validation accuracy: 0.9980988593155894

# %% [markdown]
# <h1>Classification Report</h1>

# %%
print(classification_report(y_test, predictions, target_names=labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#       German       1.00      1.00      1.00       275
#      English       1.00      1.00      1.00       267
#      Spanish       1.00      1.00      1.00       247
#
#     accuracy                           1.00       789
#    macro avg       1.00      1.00      1.00       789
# weighted avg       1.00      1.00      1.00       789

# %%
language_names = list(language_codes_files.keys())
plt.figure(figsize=(32, 32))
cm = confusion_matrix(y_test, predictions)

ax = sns.heatmap(cm, annot = True, fmt = "d")

ax.set_xlabel('Predicted Language')
ax.set_ylabel('Actual Language')
ax.set_title('Language Identification Confusion Matrix')
ax.set_xticklabels(labels.values())
ax.set_yticklabels(labels.values())
# Out:
# [Text(0, 0.5, 'German'), Text(0, 1.5, 'English'), Text(0, 2.5, 'Spanish')]

# %% [markdown]
# <h1> 21x21 Confusion Matrix</h1>
#
# <p>
# The well defined diagonal is a visual representation
# of the good performance of this language classifier.
# Although this model performs quite well, there are a few misclassifications.
# The confusion matrix gives insight into where the model makes errors.
# </p>

# %%
plt.show()

# %%
# Visualize Performance

test_languages(X_test, y_test, predictions)
# Out:
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Madam President, I should like to draw your attention to a case in which this Parliament has consistently shown an interest.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Esto significa que la autosostenibilidad de la polÃ­tica de transportes debe ser tomada en cuenta en las subvenciones de la misma manera que la participaciÃ³n de las mujeres asÃ­ como tambiÃ©n el hecho de que cada programa ha de prever tambiÃ©n la subvenciÃ³n global, de suerte que de esta manera sea posible que haya un desarrollo urbano sostenible y que haya tambiÃ©n realmente proyectos modelo en el espacio rural.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# This debate and the amendment of the directive currently in force allow us to incorporate differentiating elements which demonstrate the diversity of this Europe of ours.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Frau PrÃ¤sidentin!
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# There is support for the EU in Lapland also, so let us remember them.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# From the sixth periodic report on the regions, one can draw the hesitant conclusion that these incentives do not always have the desired effect.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Fundamentalmente, soy de la opiniÃ³n de que en muchos Ã¡mbitos del transporte habrÃ­a que aspirar a una mayor flexibilidad y a unas regulaciones elaboradas por los paÃ­ses.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# El ponente, Sr. Koch, al que damos las gracias por el trabajo que ha llevado a cabo, ha aludido a que en el fondo todo podrÃ­a estar mÃ¡s avanzado si no existiera esta demora de los CEN que son muy lentos en la elaboraciÃ³n y en la adaptaciÃ³n de la directiva.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# I agree with your analysis.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Examinaremos con cuidado la redacciÃ³n del Acta, aunque es algo que siempre hacemos.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Si se les encarga la elaboraciÃ³n de unos planes mÃ¡s ajustados a las necesidades de las correspondientes regiones y si se financian Ã©stos en caso de necesidad, entonces se puede conseguir un rendimiento mÃ¡s alto.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Doch die Kommission, die die Aufgabe hat, Leitlinien vorzulegen, tut dies nur widerwillig und bleibt vage.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# As for us in Parliament, I would like to remind you of the code of conduct between the Commission and Parliament which was signed in May.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich danke zuerst Herrn Koch fÃ¼r seinen Bericht, den ich exzellent finde und dem ich auch nicht allzuviel hinzufÃ¼gen mÃ¶chte.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Respecto al control, hemos de llegar a unos buenos acuerdos con los paÃ­ses de Europa Oriental, porque hasta el 1 de julio de 2001, o sea hasta dentro de un aÃ±o y medio, no participarÃ¡n en los tratados sobre esta materia.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Hay que reconocer que la UE ya ha apoyado, dirÃ­a que incluso extraordinariamente, el desarrollo de los paÃ­ses mÃ¡s pobres.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich habe "dafÃ¼r " gestimmt.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Gleichzeitig mÃ¶chte ich erklÃ¤ren, daÃŸ ich im Namen meiner Kollegin Frau Flautre spreche, die die Stellungnahme im Auftrag des Ausschusses fÃ¼r BeschÃ¤ftigung und soziale Angelegenheiten erarbeitet hat und leider erkrankt ist.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Otra enmienda permite a los Estados miembros establecer exigencias mÃ¡s estrictas, en especial para los tanques al vacÃ­o, cuando el trabajo o el transporte se hayan de realizar preferentemente a temperaturas considerablemente inferiores a los 20 grados bajo cero.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Meine Frage betrifft eine Angelegenheit, die am Donnerstag zur Sprache kommen wird und auf die ich dann erneut verweisen werde.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wir hoffen, daÃŸ diejenigen, die eine Ablehnung dieser Ã„nderungsantrÃ¤ge in Betracht ziehen, sowohl dem Parlament als auch ihren Arbeit suchenden BÃ¼rgern triftige GrÃ¼nde fÃ¼r ihre Entscheidung nennen kÃ¶nnen.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Por Ãºltimo, defendemos la introducciÃ³n de un cambio en el equilibrio y el mÃ©todo de desembolso de los fondos.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Esto interesa especialmente a las regiones del norte de Europa.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# I want to know whether one can raise an objection of that kind to what is merely a report, not a legislative proposal, and whether that is something I can competently do on Thursday.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Deshalb schlagen meine Fraktion und ich drei wichtige Ã„nderungen und ZusÃ¤tze vor, mit denen wir den Vorschlag in keiner Weise verwÃ¤ssern, sondern mit denen wir seine Relevanz fÃ¼r diejenigen, denen er als Anleitung dienen soll, erhÃ¶hen wollen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich wÃ¼rde mich freuen, Frau Schroedter, wenn Sie diesen Ã„nderungsantrag gerade auch unter dem Aspekt der SubsidiaritÃ¤t in Ihre positiven ErwÃ¤gungen mit einbeziehen wÃ¼rden.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# It is absolutely essential that companies in areas developing more slowly adopt the latest technology and know-how.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wenn es uns gelingt, das unternehmerische Tun in unseren armen und strukturschwachen Regionen anzukurbeln, werden wir schlieÃŸlich das Steuer herumreiÃŸen und das Vertrauen von Investoren maÃŸgeblich festigen kÃ¶nnen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Und wie Herr Simpson sehr richtig sagte, darf der ProzeÃŸ niemals als abgeschlossen, als gewonnen oder als vollendet betrachtet werden.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# For example, the question of partnership was simply left out of the central part of the structural funds.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The Commission document expected to be ready in December 1999 was delayed until January, then February, and the initial thinking does not fill me with much optimism.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Why are no-smoking areas not enforced?
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Presidenta, la Sra.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Nicht eben ein befriedigendes Ergebnis in einer Zeit, die, vor allem in den letzten Jahren, von wirtschaftlichem Aufschwung geprÃ¤gt war.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
#
#
# Another conclusion to be drawn from the report is that if financial support is to be utilised efficiently, then the measures must be brought into line with the broadly diversified means of support intended to establish a middle-class and minimum standard of living.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# As I will say in the debate on the Erika disaster, we do not wait until there is a disaster to deal with the question of safety, but we work on it even when there are no such circumstances, which simply serve to demonstrate the urgency for an effective response to this type of problem.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Esto es extraordinariamente provechoso y doy las gracias al ponente Koch por el trabajo realizado en relaciÃ³n con esta materia.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# If we look at the situation where safety advisers are concerned, in a number of countries it is compulsory to employ such safety advisers in companies as from 1 January of this year.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# ZunÃ¤chst mÃ¶chte ich dem Berichterstatter fÃ¼r die geleistete gute Arbeit und die sachliche BerÃ¼cksichtigung der eingegangenen Ã„nderungsvorschlÃ¤ge wÃ¤hrend der Behandlung im AusschuÃŸ danken.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Porque estÃ¡ claro que aunque en el seno de la UniÃ³n Europea adoptemos una regulaciÃ³n excelente, el transporte no se detiene en las fronteras sino que va mÃ¡s allÃ¡ de Ã©stas.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Nosotros rechazamos la exagerada tutela de las administraciones centrales de los Estados miembros y de la UniÃ³n, y exigimos que se reduzca la burocracia que se ha infiltrado en los procesos de elaboraciÃ³n y de ejecuciÃ³n de los programas.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wichtig ist auch, die Auswirkungen der Erweiterung auf die Strukturfonds und die Entwicklung der Gebiete in Ã¤uÃŸerster Randlage zu untersuchen.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# To this end, Europe as a whole, and each Member State individually, will have to make optimum use of all available resources and capacities, including the Structural Funds.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Constatamos que los Fondos son una condiciÃ³n necesaria pero no suficiente para conseguir la cohesiÃ³n econÃ³mica y social.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Esto significa que todos los Grupos, con excepciÃ³n de los que no pertenecen a grupos -los cuales, ciertamente, no constituyen grupo alguno- estaban de acuerdo.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# SeÃ±or Presidente, es necesario que las directrices puedan orientar correctamente y reforzar la eficacia de los programas del crÃ­tico septenio 2000-2006, de manera que el desarrollo sostenible y la creaciÃ³n de empleo, sobre todo femenino y juvenil, se hagan por fin realidad, y que se asegure el equilibrio entre la polÃ­ticas social y econÃ³mica y la polÃ­tica medioambiental.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Finally, I would say that in this matter we should learn a lesson from America, where hard work is still in fashion and success is an indication of ability and not the object of envy, as it often is here in Europe.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# In unseren Ã„nderungsantrÃ¤gen haben wir festgeschrieben, welche Bedeutung wir der Herausbildung der notwendigen Synergien zwischen den Strukturfonds, dem KohÃ¤sionsfonds und den Gemeinschaftsinitiativen beimessen, so daÃŸ ihre Anwendung auf optimale und rentabelste Weise im zunehmenden Abbau der regionalen Ungleichheiten und in der Schaffung von ArbeitsplÃ¤tzen ihren Niederschlag findet, die letztendlich die beiden Hauptziele der hier zur Debatte stehenden Fonds sind.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Da mir nur sehr wenig Zeit zur VerfÃ¼gung steht, komme ich gleich zur Sache.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# SeÃ±or Presidente, mis felicitaciones para el ponente por su informe tan minucioso.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# The time has come to implement the programmes, and so Member States should also assume their responsibilities and do their jobs properly.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Estoy de acuerdo en que el Parlamento Europeo no ha tenido ocasiÃ³n -o no se le ha dado, por ser el final de la legislatura- de hablar sobre las directrices.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# KÃ¶nnten Sie mir eine Auskunft zu Artikel 143 im Zusammenhang mit der UnzulÃ¤ssigkeit geben?
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#

#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# SchlieÃŸlich, Herr PrÃ¤sident, sind bereits die Hauptprobleme dargelegt worden, die diese Ã„nderung der Richtlinie rechtfertigen, wir sind auf die VerzÃ¶gerung beim CEN, auf die Ã„nderung einiger Vorschriften, auf die Ãœbereinstimmung zwischen dem Wortlaut der Richtlinie und dem Inhalt der AnhÃ¤nge sowie auf die Notwendigkeit einer stÃ¤rkeren PrÃ¤zisierung eingegangen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Der Berichterstatter Koch, dem wir unseren Dank fÃ¼r seine Arbeit, die er dabei geleistet hat, aussprechen, hat darauf hingewiesen, daÃŸ im Grunde genommen alles schon etwas weiter sein kÃ¶nnte, wenn es nicht dieses VersÃ¤umnis der CEN gÃ¤be, die in der Erstellung und dem Angleichen der Richtlinie sehr sÃ¤umig sind.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Considering that enlargement towards the East will create a few more problems, then it becomes clear to us all that the future credibility of the EU will depend on whether, and in what manner, we succeed in sorting out the transport situation.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Over a ten year period, the gap in average GDP has been reduced by ten percent.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Frau PrÃ¤sidentin, wenn aus der Abstimmung einwandfrei hervorgeht, wie meine Fraktion abgestimmt hat, dann werde und kann ich nichts dagegen sagen.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The first priority is to improve the competitiveness of regional economies in order to create, in all sectors, but especially in the private sector, as Mr Berend said, the maximum number of serious, worthwhile and permanent jobs, the competitiveness of regional economies, all regional economies, and in particular, Mr Evans, that of Wales, but not only of Wales.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Tristemente, es sÃ³lo un reconocimiento de las grandes dificultades que estÃ¡ atravesando Gales.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Estimados colegas, no podemos ignorar que las ganancias del mercado interior europeo se concentran en los paÃ­ses ricos y que incluso en Ã©stos no benefician a todos los sectores de la poblaciÃ³n.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die zustÃ¤ndigen Dienste haben sie nicht in die Tagesordnung aufgenommen, da sie der Meinung waren, sie seien schon in einer vorangegangenen Sitzung beantwortet worden.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Â¿Por quÃ© no se han mejorado las escaleras desde mi accidente?
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Schroedter, en nombre de la ComisiÃ³n de PolÃ­tica Regional, Transportes y Turismo, sobre la ComunicaciÃ³n de la ComisiÃ³n relativa a los Fondos estructurales y su coordinaciÃ³n con el Fondo de CohesiÃ³n: directrices para los programas del perÃ­odo 2000-2006 (COM(1999)344 - C5-0122/1999- 1999/2127(COS)).
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The negative conclusion is that the great effort made has been more efficient in harmonising the European regions' GDP and productivity than in harmonising its levels of unemployment.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Bearing this in mind, this House should, in any event, demand that, before the Community support frameworks for the period in question are approved, they be studied and submitted for debate in this Parliament, specifically in light of the guidelines that we have presented today.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# La primera prioridad es la de la mejora de la competitividad de las economÃ­as regionales para crear, en todos los sectores pero en especial en el sector privado, como ha dicho el Sr. Berend, el mÃ¡ximo de empleos serios, sÃ³lidos y duraderos.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# As an islander, however, I would like to express my dissatisfaction at the lack of recognition of island development.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Eine weitere SchluÃŸfolgerung aus dem Bericht besteht darin, daÃŸ im Sinne eines effizienten FÃ¶rdermitteleinsatzes die Abstimmung von FÃ¶rdermaÃŸnahmen mit der breit gefÃ¤cherten Mittelstands- und ExistenzgrÃ¼ndungsfÃ¶rderung erfolgen muÃŸ.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# EstÃ¡, sin duda, dentro de la lÃ­nea de las posiciones que nuestro Parlamento siempre ha adoptado.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Deshalb begrÃ¼ÃŸe ich es, wenn die Kommission die praktische Ausarbeitung und die DurchfÃ¼hrung von MaÃŸnahmen den Mitgliedstaaten und Regionen Ã¼berlÃ¤ÃŸt.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Incidentally, I would just like to address a comment to the government of my country, where there is a desire simply to ignore the horizontal Community policy concerning environmental protection and where it was maintained that there was no need to implement the FFH guideline.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The reason Mr Koch produced his sound report was because the work in the CEN and within the United Nations Economic Commission was proceeding none too expeditiously.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Ya algunos colegas han hablado del paro, del descenso de la demografÃ­a.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Considero, pues, que la pregunta oral se mantiene en el orden del dÃ­a.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# And finally, there are the cross-border aspects.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# This is the purpose of these guidelines.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Diese fÃ¼hren uns allerdings die Dringlichkeit einer effektiven Antwort auf Probleme dieser Art vor Augen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Vom Berliner Gipfel 1999 blieb dann nur noch der indikative Charakter der Leitlinien Ã¼brig.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# And let me assure you, furthermore, that when the Commission adopts the guidelines with what we call the mid-term review in mind, in line with the regulations, then the point of view of this House, as expressed in this report, will also be taken into account.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Pensemos en el tÃºnel de base del Brennero que aÃºn no ha sido discutido con profundidad.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# This does not mean that I do not see the need for competitiveness, particularly as I myself am an entrepreneur in an Objective 1 Region, that is in Brandenburg in the Federal Republic of Germany, and am only too aware of the problems and concerns of small and medium-sized enterprises.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Es geht um eine moralische Pflicht, die der EU und uns allen auferlegt ist.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# El funcionamiento de la ronda anterior de programas es tambiÃ©n muy instructiva porque nos sugiere quÃ© es lo que las directrices no deben producir.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# That is why we would recommend - and it is my impression that the Commission is also open to this idea - that we hold the debate on the Commission's long-term programme up to the year 2005 in February - and I hope that the Commission will agree on a programme before then which it will propose to us - and that, at the same time, in February we also hold the debate on the Commission's legislative programme for the year 2000.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Das ist eine sehr teure Angelegenheit und fÃ¼hrt darÃ¼ber hinaus zu groÃŸen sozialen Problemen.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# The vote will take place tomorrow at 12 p.m.
#
# (The sitting was closed at 8.25 p.m.)
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Leider gehen die neuen Leitlinien in dieselbe Richtung, und nichts deutet darauf hin, daÃŸ ihre Umsetzung daran etwas Ã¤ndern wird.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Pido la conformidad de ustedes.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Jetzt, wo die Programmierungsphasen weit vorangeschritten sind, macht es wenig Sinn, alles zurÃ¼ckzuholen.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
#
#
# (El Parlamento aprueba el orden de los trabajos asÃ­ modificado)
#
#
# Consejeros de seguridad para el transporte de mercancÃ­as peligrosas
#
# De conformidad con el orden del dÃ­a, se procede al debate de la recomendaciÃ³n para la segunda lectura (A5-0105/1999) respecto de la posiciÃ³n comÃºn del Consejo con vistas a la adopciÃ³n de la directiva del Parlamento Europeo y del Consejo relativa a los requisitos mÃ­nimos aplicables al examen de los consejeros de seguridad para el transporte de mercancÃ­as peligrosas por carretera, ferrocarril o por vÃ­a navegable (C5-0208/1999 - 1998/0106(COD)).
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Some Member States have been in breach of the principle of subsidiarity and cut national regional funds when regional aid coming via the Union has been increased.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Por lo tanto, doy mi sincera aprobaciÃ³n a que la ComisiÃ³n deje en manos de los Estados miembros y de las regiones la elaboraciÃ³n prÃ¡ctica y la puesta en marcha de estas medidas.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Danken mÃ¶chte ich sowohl dem Berichterstatter fÃ¼r seinen Ã¼beraus akribischen und sachkundigen Bericht als auch der Kommission fÃ¼r den von ihr eingebrachten Vorschlag.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Nach den Worten ihres PrÃ¤sidenten ist sie dazu in der Lage.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# El debate queda cerrado.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# SeÃ±ora Presidenta, quisiera llamar la atenciÃ³n de usted acerca de un caso del que se ha ocupado una y otra vez este Parlamento.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Needless to say, safety on roads, railways and inland waterways is of key importance and, given the international nature of these types of transport, training for safety advisors should also be harmonised, therefore, as well as the requirements of the new ADR, for example, which is under way.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# By shifting the criteria from the regions to the Member States, we can avoid a great deal of problems later on.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Der dritte Punkt wurde auch schon erwÃ¤hnt.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Pero a mÃ­ me gustarÃ­a resaltar aquÃ­ que este punto de partida nos indica los desafÃ­os ante los que nos encontramos: mantener la poblaciÃ³n en las zonas rurales, ante los cambios que se estÃ¡n produciendo en todo tipo de actividades econÃ³micas debido a la creciente pÃ©rdida de peso del sector agrÃ­cola entre las diversas fuentes de renta de la sociedad rural.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Zu den Worten von Herrn Swoboda Ã¼ber die TÃ¤tigkeit des CEN mÃ¶chte ich sagen, daÃŸ wir sie drÃ¤ngen, ihre Arbeit maximal zu beschleunigen, denn es wÃ¤re dramatisch, wenn wir trotz der neuen Frist nach etwas mehr als einem Jahr vor den gleichen Schwierigkeiten stehen wÃ¼rden, weil die Arbeiten nicht zum AbschluÃŸ gebracht wurden.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Es el caso de Alexander Nikitin.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich gehe mit der Berichterstatterin konform, daÃŸ das Kommissionsdokument leider zu wenig Empfehlungen an die Mitgliedstaaten zur Verwaltungsvereinfachung enthÃ¤lt, und unterstreiche Forderungen wie Konzentration bei Verhandlungen auf die FÃ¶rderung eines gÃ¼nstigen Umfeldes fÃ¼r arbeitsintensive kleine und mittelstÃ¤ndische Unternehmen, auf eine klare Zielsetzung fÃ¼r alternative Finanzierungsquellen einschlieÃŸlich Regelungen fÃ¼r Risikokapital und private Finanzierung, auf betriebliche Starthilfen einschlieÃŸlich neuer Informationstechnologien sowie Investitionen in innovativen Bereichen.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# I am particularly in favour of a proposed amendment tabled by my Group to paragraph 10, to ensure an appropriate level of private sector involvement in the planning and implementation of the projects.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# It must, however, be stressed that the guidelines under discussion are related only to the Structural Funds, whose Objectives 1 and 2 specifically adopt the diversification of rural society as a priority.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Indem sie maÃŸgeschneiderte Programme fÃ¼r die jeweiligen Regionen entwickeln und dafÃ¼r erforderlichenfalls Mittel bewilligen kÃ¶nnen, lÃ¤ÃŸt sich ein grÃ¶ÃŸerer Effekt erzielen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Der Erfolg von Projekten, die mit Hilfe der Union umgesetzt werden, wird hÃ¤ufig durch langsame Entscheidungsfindung und komplizierte Verwaltungsverfahren beeintrÃ¤chtigt.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Para terminar, quisiera destacar que las polÃ­ticas estructurales en su conjunto requieren mayor flexibilidad, de suerte que se adapten a las circunstancias cambiantes y que respondan de ese modo a los nuevos retos y oportunidades que se presentan con la llegada del nuevo milenio, para el que todos hacemos los mejores votos.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
#

#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wir geben unserer Besorgnis Ã¼ber Meldungen Ausdruck, denen wir entnehmen, daÃŸ die Bedeutung dieses Ziels in den Anschauungen der Kommission zunehmend nachlÃ¤ÃŸt.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Las personas que tienen que manejar estos riesgos, deben cumplir por lo tanto unos altos requisitos.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Escuchemos ahora al Sr. Wurtz, que hablarÃ¡ en contra de la peticiÃ³n.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# FÃ­jense en los accidentes en la carretera de los Ãºltimos aÃ±os.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# We must not content ourselves with sealing another hole in the safety net and shutting our eyes to the fact that, where transport safety in Europe is concerned, there is still much more to be done.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Es ist fÃ¼r sie erforderlich, daÃŸ die politische Dimension funktioniert, daÃŸ Verantwortlichkeiten bestehen, daÃŸ eine Kommunikation mit den BÃ¼rgern vorhanden ist.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# However, even though the role of agriculture is not exclusive, it is still essential, not only to prevent economic and social disintegration and the creation of ghost towns, but also because farmers play a fundamental role in managing the land, in preserving biodiversity and in protecting the environment.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# It must be remembered that, currently, the European Union' s overall competitiveness is, in general terms, 81% of that of the United States of America and that this figure will only improve if the figure for our competitive units, that is the regions, also improves.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Por esta razÃ³n, no nos queda mÃ¡s que esperar -y deberÃ­amos decidir esto en esta semana- que en el 2001 dispongamos, por fin, de regulaciones comunitarias para el transporte de mercancÃ­as peligrosas por carretera, de suerte que en este punto tengamos un poco de seguridad jurÃ­dica y tambiÃ©n un poco mÃ¡s de seguridad en nuestras carreteras.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die Folgen lassen nicht auf sich warten.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# AsÃ­ pues, nos vemos obligados a construir repetidas veces, para las mismas personas y en el mismo paÃ­s, escuelas y hospitales, toda la infraestructura una vez mÃ¡s.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Las nuevas directrices se mueven desgraciadamente en el mismo sentido y nada hace pensar que pueda cambiar con la aplicaciÃ³n de estas directrices.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Die Strukturfonds haben vor allem durch die Modernisierung der StraÃŸen, der Wasseraufbereitung und der jeweiligen Verkehrsnetze maÃŸgeblich zur Entwicklung der lÃ¤ndlichen wie auch stÃ¤dtischen RÃ¤ume in den EU-LÃ¤ndern in Randlage beigetragen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# ...
# Actual Language: German
# Input Sentence:
# Die auf der heutigen Tagesordnung stehende Ã„nderung der Richtlinie bewirkt also keine Ã„nderung der in der Gemeinschaft bestehenden Harmonisierung der Gefahrguttransporte.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# How long do we actually intend to allow this kind of development to go on for, resulting as it does in the widening gulf between poor and wealthy regions?
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Beim Abfassen des Protokolls werden wir mit groÃŸer Sorgfalt vorgehen.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Quisiera que en los Grupos nos pudiÃ©ramos preparar razonablemente para un debate sobre el programa para cinco aÃ±os.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Jetzt zu inhaltlichen Aspekten der Leitlinien.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# El desvÃ­o consiguiente del transporte por esta causa llevÃ³ hasta el lÃ­mite de lo soportable a muchos miles de ciudadanos de la UE.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Moreover, the guidelines may not substitute for the programming or the ex ante assessments which must be the tool used to specify priorities and the effectiveness of these programmes.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Der Bericht weist aber nach, daÃŸ sich regionale Unterschiede auf dem Arbeitsmarkt sogar weiter verschÃ¤rft haben.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Das bedeutet, daÃŸ lokale GebietskÃ¶rperschaften und nationale Regierungen bei der Verwendung dieser Mittel eng und partnerschaftlich zusammenarbeiten mÃ¼ssen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# (Das Parlament lehnt den Antrag mit 164 Ja-Stimmen, 166 Nein-Stimmen und 7 Enthaltungen ab.)
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Summa summarum halte ich den von dem Berichterstatter eingebrachten AbÃ¤nderungsantrag in jeder Hinsicht fÃ¼r logisch und kann ihn deshalb voll und ganz unterstÃ¼tzen.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# El informe estipula que se debe aplicarse a pesar del principio de estabilidad relativa.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich hoffe, daÃŸ dort in Ihrem Sinne entschieden wird.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# SeÃ±or Presidente, yo tambiÃ©n quiero felicitar a la ponente por el excelente trabajo que ha hecho.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# There is, in fact, a risk of a military coup in the future.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# SeÃ±or Presidente, tenemos que ser flexibles a la hora de dictar normas.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die Entwicklung der sozialen und wirtschaftlichen Lage ist schlieÃŸlich entscheidend dafÃ¼r, wie die BÃ¼rger Europas den Erfolg unserer Arbeit bewerten.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# yourselves, on the subject of this regional policy and what might one day be a European regional planning policy.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Das ist leider nicht geschehen, was allerdings nicht Herrn Bernie, sondern der alten Kommission anzulasten ist.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Quiero resaltar especialmente la importancia que concede la ComisiÃ³n a la cuestiÃ³n del desarrollo sostenible, al aumento del empleo, con especial atenciÃ³n a la igualdad de oportunidades, asÃ­ como a los asuntos relacionados con los transportes.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# In Italien beispielsweise gab es in den letzten Jahren Probleme bei der Inanspruchnahme der Strukturfonds, wobei die HauptgrÃ¼nde in einer aufgeblÃ¤hten BÃ¼rokratie, in unzulÃ¤nglichen Informationen sowie darin lagen, daÃŸ die Wirtschafts- und Sozialakteure auf lokaler Ebene zu wenig beteiligt wurden.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Well, the Structural Funds have helped to apply a brake to this process.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Por consiguiente, me pregunto a quÃ© se debe que los recursos de los Fondos estructurales no se hayan utilizado de manera eficiente.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Now to the form.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# I should now like to comment on the issue itself.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# En la Conferencia de Presidentes, tuvimos un debate muy minucioso.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The first is the fundamental, central importance that we continue to give to the principle of economic and social cohesion.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# In the future, we must also develop indicators so that measures can be targeted at the right time at the right place.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# At this stage, I would simply like to say that I would like to see it integrated into the programming for Objective 2 rural areas, in the way that the EAGGF Guidance Section is for Objective 1 regions.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Wir fordern diejenigen Mitgliedstaaten, die noch keine ausreichende FÃ¶rdergebietskarte eingereicht haben, auf, dies umgehend zu tun, und erwarten von der Kommission natÃ¼rlich auch, daÃŸ sie die operationellen Programme der Regionen fÃ¼r die neue FÃ¶rderperiode von 2000 bis 2006 im Lichte dieser Ergebnisse des sechsten periodischen Berichtes zÃ¼gig prÃ¼ft und alles tut, damit diese FÃ¶rderperiode ohne zeitliche VerzÃ¶gerung auch vor Ort ordentlich beginnen kann.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die Leitlinien mÃ¼ssen konkreter Gradmesser dafÃ¼r sein, ob der Artikel 1 der Verordnung wirklich umgesetzt wird.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Unfortunately, the excellent Schroedter report did not take account of this criterion, despite the fact that there is considerable evidence to show - as we shall see later in the Berend report - how, in fact, these funds are providing splendid assistance to the most backward regions in order to bridge the gulf that separates them from Europe' s most highly-developed regions.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Therefore, we support the establishment of an agricultural and rural development policy which is consistent with the objectives we have set.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# This means that there must be a comprehensive partnership between local authorities and national governments with regard to how these funds are to be spent.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die erste bezieht sich darauf, daÃŸ bedeutsame Fortschritte in der territorialen und sozialen KohÃ¤sion im gesamten Gebiet der Union erreicht worden sind und die Gemeinschaftsfonds einen wichtigen, wenn auch nicht entscheidenden Faktor beim Abbau der regionalen Ungleichheiten darstellen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Da die Kommission durch die VizeprÃ¤sidentin, Frau de Palacio, vertreten ist, halte ich es fÃ¼r zweckmÃ¤ÃŸig, vor der Abstimmung die Position der Kommission hinsichtlich ihrer Bereitschaft zur Vorstellung des Programms, so wie es vereinbart war, zu erfahren.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# In ganz kurzen Worten mÃ¶chte ich auch fÃ¼r die BeitrÃ¤ge der verschiedenen Abgeordneten danken und Ihnen, meine Damen und Herren, sagen, daÃŸ die Kommission der Sicherheit im Verkehrswesen PrioritÃ¤t einrÃ¤umt.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# I suggest Mr Evans goes back and reads the regulation.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Erstens: Der Bericht prÃ¼ft die Wirkung des Instrumentes an sich.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Por consiguiente, vamos a revisarlas con seriedad para que todo estÃ© en orden.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Sie stellen ein wesentliches Hilfsmittel fÃ¼r die Mitgliedstaaten dar.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Es preciso, pues, vincular mÃ¡s la financiaciÃ³n estructural a la creaciÃ³n de puestos de trabajo.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Mr President, I would like to say a few words in order to highlight two points made in these reports which are of fundamental strategic importance to the way we see the Union.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wir wissen nicht, was passiert.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# I wish to assure you, firstly, that the merging of the periodic reports and the report on cohesion should not entail any loss of information or loss of interest as regards the content of the report on cohesion which is, as far as I am concerned, Mr Berend, an extremely important instrument, not only to provide information on what has been achieved in a transparent and rigorous manner, so that future guidelines may be examined or evaluated, but also to create a public debate involving the citizens of Europe and, furthermore, with the elected representatives, i.e.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# (Beifall von der PPE-DE-Fraktion)
#
#
# Frau PrÃ¤sidentin!
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Considero que se han tenido satisfactoriamente en cuenta nuestras enmiendas de la primera lectura.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Dazu kam es nicht.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# Furthermore, three quarters of our farm workers are part-time and require supplements to their incomes.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Es ist richtig, daÃŸ Ihr Haus erst spÃ¤t mit der Sache befaÃŸt worden ist.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# They have either been accepted or transposed with no change in the substance, or they have been rejected because the corresponding European arrangements have not been included, for example a system of penalties for violations of the rules or a complex classification structure for related groups of questions.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Ich konnte sie nÃ¤mlich nicht elektronisch abgeben, weil ich die Karte nicht habe.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Nach dem Vorschlag der Kommission wÃ¤re ein Grenzwert von -20 ÂºC ausreichend.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Die ModalitÃ¤ten fÃ¼r die AusÃ¼bung dieser der Kommission Ã¼bertragenen DurchfÃ¼hrungsbefugnisse wurden durch RatsbeschluÃŸ vom Juni 1999 neu geregelt.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Man muÃŸ das unbedingt koppeln mit einer nachfrageorientierten Wirtschaftspolitik, damit wir Ã¼berhaupt die Chance haben, die soziale Situation in diesen Gebieten zu verbessern.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Sus SeÃ±orÃ­as han solicitado un debate sobre el tema para los prÃ³ximos dÃ­as, en el curso de este perÃ­odo de sesiones.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Auch in diesem Zusammenhang muÃŸ die entscheidende Bedeutung der kleinen und mittleren Unternehmen als Motor fÃ¼r BeschÃ¤ftigung und regionale Entwicklung hervorgehoben werden.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# That is why my Group firmly rejects the proposal made by the Socialist Group.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Para terminar, dirÃ­a que, en este aspecto, deberÃ­amos tomar ejemplo de los Estados Unidos, donde la laboriosidad se ha vuelto a poner de moda y el Ã©xito es una manifestaciÃ³n de la valÃ­a personal, y no objeto de envidia, como ocurre muchas veces aquÃ­ en Europa.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Damit die Ziele dieser Politiken mÃ¶glichst umfassend verwirklicht werden kÃ¶nnen, mÃ¼ssen sie koordiniert und auf der Grundlage wohldurchdachter, sinnvoller Leitlinien umgesetzt werden.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# In brief, I would like to say that we are entering the period when we are called upon to manage the programming for 2000-2006, which must be no routine period for the good reason that we have two major challenges to face.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wie viele andere appelliere auch ich an die Kommission, zÃ¼gig ReformvorschlÃ¤ge zu unterbreiten.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# The rapporteur has also quite rightly stated that Parliament was not heard in time regarding the guidelines.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Dies liegt im besonderen Interesse nordeuropÃ¤ischer Regionen.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# I wish to confirm the great importance the Commission attaches, and shall attach, to the urban dimension of our cohesion policy.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
#
# Our amendments from the first reading have, I believe, been taken into account very satisfactorily.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# So Parliament should send a message, since that is the wish of the vast majority.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wir wollen die Wettbewerbsbedingungen nicht einseitig fÃ¼r einige LÃ¤nder verschlechtern und fÃ¼r LÃ¤nder wie Ã–sterreich oder andere TransitlÃ¤nder verbessern.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Hubo una votaciÃ³n sobre este punto.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Gleichwohl wissend, daÃŸ dies nur ein kleiner Schritt zu mehr Verkehrssicherheit ist, bitte ich Sie um die Zustimmung zu diesem Bericht.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# SeÃ±or Presidente, seÃ±or Comisario, SeÃ±orÃ­as, en este minuto y medio ante todo quiero felicitar a nuestra colega, la Sra.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Herr PrÃ¤sident, meine Damen und Herren Abgeordneten!
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# How can the Union respond to the challenges of global development in a way that the less developed areas can remain a part of that development?
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Wir brauchen nur an den schweren Unfall im Mont-Blanc-Tunnel vor etwa einem Jahr zu denken - auch der Tauerntunnel gehÃ¶rt dazu.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# That is why - and this is the conclusion we can draw from this report - promoting competitiveness within industry and infrastructure for economic activity must be central to the structural policy, in that order.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
#
# Ruego que se reconsidere esta decisiÃ³n porque esto no es asÃ­.
#
#
# Prediction: Spanish
# Actual Language: Spanish
# Input Sentence:
# Por ejemplo en BÃ©lgica, los PaÃ­ses Bajos y algunos otros paÃ­ses donde, habiendo niebla, los camiones con mercancÃ­as peligrosas seguÃ­an en ruta cuando deberÃ­an haber parado en esos momentos.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
# Hier dÃ¼rfen sich die Mitgliedstaaten auch nicht ihrer Verantwortung entziehen.
#
#
# Prediction: German
# Actual Language: German
# Input Sentence:
#
# Die Abstimmung findet morgen um 12.00 Uhr statt.
#
#
# Prediction: English
# Actual Language: English
# Input Sentence:
# As you know, it is up to each State to redistribute part of the total appropriation.

# %%
# Twitter data

pred = text_clf.predict(['I\'ve #got a feeling! 👌'])

labels[float(pred[0])]
# Out:
# 'English'
